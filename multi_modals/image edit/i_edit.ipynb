# %%
from openai import OpenAI
from dotenv import load_dotenv, find_dotenv

_: bool = load_dotenv(find_dotenv())

client : OpenAI = OpenAI()

# %%
image  = open("background_image.png", "rb")
mask = open("masked.png", "rb")

response = client.images.edit(
    model="dall-e-2",
    image=image,
    mask=mask,
    prompt="A sunny day with a sun and greenhouse",
    size="512x512",
    n=1,
)
print(response)
image_url = response.data[0].url
print(image_url)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[19], line 4
#       1 image  = open("background_image.png", "rb")
#       2 mask = open("masked.png", "rb")
# ----> 4 response = client.images.edit(
#       5     model="dall-e-2",
#       6     image=image,
#       7     mask=mask,
#       8     prompt="A sunny day with a sun and greenhouse",
#       9     size="512x512",
#      10     n=1,
#      11 )
#      12 print(response)
#      13 image_url = response.data[0].url
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openai\resources\images.py:183, in Images.edit(self, image, prompt, mask, model, n, response_format, size, user, extra_headers, extra_query, extra_body, timeout)
#     177 if files:
#     178     # It should be noted that the actual Content-Type header that will be
#     179     # sent to the server will contain a `boundary` parameter, e.g.
#     180     # multipart/form-data; boundary=---abc--
#     181     extra_headers = {"Content-Type": "multipart/form-data", **(extra_headers or {})}
# --> 183 return self._post(
#     184     "/images/edits",
#     185     body=maybe_transform(body, image_edit_params.ImageEditParams),
#     186     files=files,
#     187     options=make_request_options(
#     188         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     189     ),
#     190     cast_to=ImagesResponse,
#     191 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openai\_base_client.py:1096, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1082 def post(
#    1083     self,
#    1084     path: str,
#    (...)
#    1091     stream_cls: type[_StreamT] | None = None,
#    1092 ) -> ResponseT | _StreamT:
#    1093     opts = FinalRequestOptions.construct(
#    1094         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1095     )
# -> 1096     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openai\_base_client.py:856, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     847 def request(
#     848     self,
#     849     cast_to: Type[ResponseT],
#    (...)
#     854     stream_cls: type[_StreamT] | None = None,
#     855 ) -> ResponseT | _StreamT:
# --> 856     return self._request(
#     857         cast_to=cast_to,
#     858         options=options,
#     859         stream=stream,
#     860         stream_cls=stream_cls,
#     861         remaining_retries=remaining_retries,
#     862     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openai\_base_client.py:908, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     905     if not err.response.is_closed:
#     906         err.response.read()
# --> 908     raise self._make_status_error_from_response(err.response) from None
#     909 except httpx.TimeoutException as err:
#     910     if response is not None:
#
# BadRequestError: Error code: 400 - {'error': {'code': None, 'message': 'Invalid input mask - mask size must match image size 512x512, got 711x400 instead.', 'param': None, 'type': 'invalid_request_error'}}

# %%
# image variation

response = client.images.create_variation(
image=open('png-2702691_1280.png'),
model='dall-e-2',
size='1024x1024',
n=2

)

image_url = response.data[0].url
print(image_url)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 # image variation
# ----> 3 response = client.images.create_variation(
#       4 image=open('png-2702691_1280.png'),
#       5 model='dall-e-2',
#       6 size='1024x1024',
#       7 n=2
#       8
#       9 )
#      11 image_url = response.data[0].url
#      12 print(image_url)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openai\resources\images.py:99, in Images.create_variation(self, image, model, n, response_format, size, user, extra_headers, extra_query, extra_body, timeout)
#      93 if files:
#      94     # It should be noted that the actual Content-Type header that will be
#      95     # sent to the server will contain a `boundary` parameter, e.g.
#      96     # multipart/form-data; boundary=---abc--
#      97     extra_headers = {"Content-Type": "multipart/form-data", **(extra_headers or {})}
# ---> 99 return self._post(
#     100     "/images/variations",
#     101     body=maybe_transform(body, image_create_variation_params.ImageCreateVariationParams),
#     102     files=files,
#     103     options=make_request_options(
#     104         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     105     ),
#     106     cast_to=ImagesResponse,
#     107 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openai\_base_client.py:1096, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1082 def post(
#    1083     self,
#    1084     path: str,
#    (...)
#    1091     stream_cls: type[_StreamT] | None = None,
#    1092 ) -> ResponseT | _StreamT:
#    1093     opts = FinalRequestOptions.construct(
#    1094         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1095     )
# -> 1096     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openai\_base_client.py:856, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     847 def request(
#     848     self,
#     849     cast_to: Type[ResponseT],
#    (...)
#     854     stream_cls: type[_StreamT] | None = None,
#     855 ) -> ResponseT | _StreamT:
# --> 856     return self._request(
#     857         cast_to=cast_to,
#     858         options=options,
#     859         stream=stream,
#     860         stream_cls=stream_cls,
#     861         remaining_retries=remaining_retries,
#     862     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openai\_base_client.py:876, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     873 self._prepare_options(options)
#     875 retries = self._remaining_retries(remaining_retries, options)
# --> 876 request = self._build_request(options)
#     877 self._prepare_request(request)
#     879 response = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openai\_base_client.py:469, in BaseClient._build_request(self, options)
#     466         kwargs["data"] = self._serialize_multipartform(json_data)
#     468 # TODO: report this error to httpx
# --> 469 return self._client.build_request(  # pyright: ignore[reportUnknownMemberType]
#     470     headers=headers,
#     471     timeout=self.timeout if isinstance(options.timeout, NotGiven) else options.timeout,
#     472     method=options.method,
#     473     url=self._prepare_url(options.url),
#     474     # the `Query` type that we use is incompatible with qs'
#     475     # `Params` type as it needs to be typed as `Mapping[str, object]`
#     476     # so that passing a `TypedDict` doesn't cause an error.
#     477     # https://github.com/microsoft/pyright/issues/3526#event-6715453066
#     478     params=self.qs.stringify(cast(Mapping[str, Any], params)) if params else None,
#     479     json=json_data,
#     480     files=options.files,
#     481     **kwargs,
#     482 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpx\_client.py:358, in BaseClient.build_request(self, method, url, content, data, files, json, params, headers, cookies, timeout, extensions)
#     352     timeout = (
#     353         self.timeout
#     354         if isinstance(timeout, UseClientDefault)
#     355         else Timeout(timeout)
#     356     )
#     357     extensions = dict(**extensions, timeout=timeout.as_dict())
# --> 358 return Request(
#     359     method,
#     360     url,
#     361     content=content,
#     362     data=data,
#     363     files=files,
#     364     json=json,
#     365     params=params,
#     366     headers=headers,
#     367     cookies=cookies,
#     368     extensions=extensions,
#     369 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpx\_models.py:338, in Request.__init__(self, method, url, params, headers, cookies, content, data, files, json, stream, extensions)
#     336 if stream is None:
#     337     content_type: typing.Optional[str] = self.headers.get("content-type")
# --> 338     headers, stream = encode_request(
#     339         content=content,
#     340         data=data,
#     341         files=files,
#     342         json=json,
#     343         boundary=get_multipart_boundary_from_content_type(
#     344             content_type=content_type.encode(self.headers.encoding)
#     345             if content_type
#     346             else None
#     347         ),
#     348     )
#     349     self._prepare(headers)
#     350     self.stream = stream
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpx\_content.py:210, in encode_request(content, data, files, json, boundary)
#     208     return encode_content(content)
#     209 elif files:
# --> 210     return encode_multipart_data(data or {}, files, boundary)
#     211 elif data:
#     212     return encode_urlencoded_data(data)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpx\_content.py:155, in encode_multipart_data(data, files, boundary)
#     152 def encode_multipart_data(
#     153     data: RequestData, files: RequestFiles, boundary: Optional[bytes]
#     154 ) -> Tuple[Dict[str, str], MultipartStream]:
# --> 155     multipart = MultipartStream(data=data, files=files, boundary=boundary)
#     156     headers = multipart.get_headers()
#     157     return headers, multipart
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpx\_multipart.py:208, in MultipartStream.__init__(self, data, files, boundary)
#     204 self.boundary = boundary
#     205 self.content_type = "multipart/form-data; boundary=%s" % boundary.decode(
#     206     "ascii"
#     207 )
# --> 208 self.fields = list(self._iter_fields(data, files))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpx\_multipart.py:222, in MultipartStream._iter_fields(self, data, files)
#     220 file_items = files.items() if isinstance(files, typing.Mapping) else files
#     221 for name, value in file_items:
# --> 222     yield FileField(name=name, value=value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\httpx\_multipart.py:129, in FileField.__init__(self, name, value)
#     125     raise TypeError(
#     126         "Multipart file uploads require 'io.BytesIO', not 'io.StringIO'."
#     127     )
#     128 if isinstance(fileobj, io.TextIOBase):
# --> 129     raise TypeError(
#     130         "Multipart file uploads must be opened in binary mode, not text mode."
#     131     )
#     133 self.filename = filename
#     134 self.file = fileobj
#
# TypeError: Multipart file uploads must be opened in binary mode, not text mode.
